# %% [markdown]
# <a href="https://colab.research.google.com/github/Sethumadhavan004/Data-Science-Concepts-Lab/blob/main/Tweet_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("/content/Twitter.csv")
df.head()
# Out:
#              status_id                                               text  \
# 0  1046207313588236290  Entitled, obnoxious, defensive, lying weasel. ...
# 1  1046207328113086464  Thank you  and  for what you did for the women...
# 2  1046207329589493760  Knitting (s) &amp; getting ready for January 1...
# 3  1046207341283168256  Yep just like triffeling women weaponized thei...
# 4  1046207347016826880  No, the President wants to end  movement posin...
#
#              created_at  favorite_count  retweet_count         location  \
# 0  2018-09-30T01:17:15Z             5.0            1.0      McAllen, TX
# 1  2018-09-30T01:17:19Z             5.0            2.0        Tampa, FL
# 2  2018-09-30T01:17:19Z             0.0            0.0     St Cloud, MN
# 3  2018-09-30T01:17:22Z             1.0            0.0  flyover country
# 4  2018-09-30T01:17:23Z             0.0            0.0            World
#
#    followers_count  friends_count  statuses_count  category
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35345 entries, 0 to 35344
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   status_id        35345 non-null  int64
#  1   text             35163 non-null  object
#  2   created_at       35344 non-null  object
#  3   favorite_count   35344 non-null  float64
#  4   retweet_count    35344 non-null  float64
#  5   location         26516 non-null  object
#  6   followers_count  35344 non-null  float64
#  7   friends_count    35344 non-null  float64
#  8   statuses_count   35344 non-null  float64
#  9   category         35344 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#           status_id  favorite_count  retweet_count  followers_count  \
# count  3.534500e+04    35344.000000   35344.000000     3.534400e+04
# mean   1.046770e+18        7.383318       2.988032     2.600570e+04
# std    3.115625e+14      116.249531      46.367577     5.862500e+05
# min    1.046207e+18        0.000000       0.000000     0.000000e+00
# 25%    1.046490e+18        0.000000       0.000000     1.280000e+02
# 50%    1.046788e+18        0.000000       0.000000     6.500000e+02
# 75%    1.047055e+18        2.000000       0.000000     2.893000e+03
# max    1.047281e+18     8741.000000    3332.000000     4.218360e+07
#
#        friends_count  statuses_count      category
# count   35344.000000    3.534400e+04  35344.000000
# mean     5570.225526    4.223597e+04      0.133233
# std     38230.150379    1.692751e+05      0.339832
# min         0.000000    1.000000e+00      0.000000
# 25%       222.000000    2.119000e+03      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# status_id             0
# text                182
# created_at            1
# favorite_count        1
# retweet_count         1
# location           8829
# followers_count       1
# friends_count         1
# statuses_count        1
# category              1
# dtype: int64

# %%
df['text'].fillna('',inplace=True)
df['text']
# Out:
# 0        Entitled, obnoxious, defensive, lying weasel. ...
# 1        Thank you  and  for what you did for the women...
# 2        Knitting (s) &amp; getting ready for January 1...
# 3        Yep just like triffeling women weaponized thei...
# 4        No, the President wants to end  movement posin...
#                                ...
# 35340     So much . Mine was different, I don't know wh...
# 35341    Why haven't Dems put out a commercial of Kavan...
# 35342    So  is not for Dems.👌America gets it you reall...
# 35343    Well, he's got the  vote sealed up: Trump Sees...
# 35344    Trump and his cronies are the worst. But what’...
# Name: text, Length: 35345, dtype: object

# %%
df['location'].fillna('',inplace=True)
df['location']
# Out:
# 0                        McAllen, TX
# 1                          Tampa, FL
# 2                       St Cloud, MN
# 3                    flyover country
# 4                              World
#                     ...
# 35340                    Nevada, USA
# 35341
# 35342    South Western, Pennsylvania
# 35343                        Chicago
# 35344
# Name: location, Length: 35345, dtype: object

# %%
df=df.drop(['status_id','created_at'],axis=1)
df.head()
# Out:
#                                                 text  favorite_count  \
# 0  Entitled, obnoxious, defensive, lying weasel. ...             5.0
# 1  Thank you  and  for what you did for the women...             5.0
# 2  Knitting (s) &amp; getting ready for January 1...             0.0
# 3  Yep just like triffeling women weaponized thei...             1.0
# 4  No, the President wants to end  movement posin...             0.0
#
#    retweet_count         location  followers_count  friends_count  \
# 0            1.0      McAllen, TX           2253.0         2303.0
# 1            2.0        Tampa, FL           2559.0         4989.0
# 2            0.0     St Cloud, MN             16.0          300.0
# 3            0.0  flyover country           3573.0         3732.0
# 4            0.0            World            294.0          312.0
#
#    statuses_count  category
# 0         23856.0       0.0
# 1         19889.0       0.0
# 2             9.0       0.0
# 3         38361.0       1.0
# ...

# %%
x=df.iloc[:,:-1]
x
# Out:
#                                                     text  favorite_count  \
# 0      Entitled, obnoxious, defensive, lying weasel. ...             5.0
# 1      Thank you  and  for what you did for the women...             5.0
# 2      Knitting (s) &amp; getting ready for January 1...             0.0
# 3      Yep just like triffeling women weaponized thei...             1.0
# 4      No, the President wants to end  movement posin...             0.0
# ...                                                  ...             ...
# 35340   So much . Mine was different, I don't know wh...             1.0
# 35341  Why haven't Dems put out a commercial of Kavan...             1.0
# 35342  So  is not for Dems.👌America gets it you reall...             0.0
# 35343  Well, he's got the  vote sealed up: Trump Sees...             8.0
# 35344  Trump and his cronies are the worst. But what’...             NaN
#
#        retweet_count                     location  followers_count  \
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        0.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 35340    0.0
# 35341    0.0
# 35342    0.0
# 35343    0.0
# 35344    NaN
# Name: category, Length: 35345, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer=CountVectorizer()
x_train_text=vectorizer.fit_transform(x_train['text'])
x_train_text
# Out:
# <26508x22397 sparse matrix of type '<class 'numpy.int64'>'
# 	with 507113 stored elements in Compressed Sparse Row format>

# %%
x_test_text=vectorizer.transform(x_test['text'])
x_test_text
# Out:
# <8837x22397 sparse matrix of type '<class 'numpy.int64'>'
# 	with 164122 stored elements in Compressed Sparse Row format>

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()

# %%
model.fit(x_train_text,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model.predict(x_test_text)
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 1.])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-b1de0f5074bc> in <cell line: 2>()
#       1 from sklearn. metrics import accuracy_score, classification_report
# ----> 2 accuracy = accuracy_score (y_test, y_pred) * 100
#       3 print ('Accuracy of the model is {:.2f}'.format(accuracy))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     190
#     191             try:
# --> 192                 return func(*args, **kwargs)
#     193             except InvalidParameterError as e:
#     194                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     219
#     220     # Compute accuracy for each possible representation
# ...
